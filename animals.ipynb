# %%
pip install matplotlib tensorflow
# Out:
# Collecting matplotlib
#   Using cached matplotlib-3.10.8-cp311-cp311-win_amd64.whl (8.1 MB)
# Collecting tensorflow
#   Using cached tensorflow-2.20.0-cp311-cp311-win_amd64.whl (331.8 MB)
# Collecting contourpy>=1.0.1
#   Using cached contourpy-1.3.3-cp311-cp311-win_amd64.whl (225 kB)
# Collecting cycler>=0.10
#   Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting fonttools>=4.22.0
#   Using cached fonttools-4.61.1-cp311-cp311-win_amd64.whl (2.3 MB)
# Collecting kiwisolver>=1.3.1
#   Using cached kiwisolver-1.4.9-cp311-cp311-win_amd64.whl (73 kB)
# Collecting numpy>=1.23
#   Using cached numpy-2.4.0-cp311-cp311-win_amd64.whl (12.6 MB)
# Requirement already satisfied: packaging>=20.0 in c:\users\srija\appdata\roaming\python\python311\site-packages (from matplotlib) (25.0)
# Collecting pillow>=8
#   Downloading pillow-12.1.0-cp311-cp311-win_amd64.whl (7.0 MB)
#      ---------------------------------------- 7.0/7.0 MB 195.4 kB/s eta 0:00:00
# Collecting pyparsing>=3
#   Downloading pyparsing-3.3.1-py3-none-any.whl (121 kB)
#      -------------------------------------- 121.8/121.8 kB 1.0 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\srija\appdata\roaming\python\python311\site-packages (from matplotlib) (2.9.0.post0)
# Collecting absl-py>=1.0.0
#   Downloading absl_py-2.3.1-py3-none-any.whl (135 kB)
#      -------------------------------------- 135.8/135.8 kB 1.0 MB/s eta 0:00:00
# Collecting astunparse>=1.6.0
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting flatbuffers>=24.3.25
#   Downloading flatbuffers-25.12.19-py2.py3-none-any.whl (26 kB)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1
#   Downloading gast-0.7.0-py3-none-any.whl (22 kB)
# Collecting google_pasta>=0.1.1
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      ---------------------------------------- 57.5/57.5 kB 1.5 MB/s eta 0:00:00
# Collecting libclang>=13.0.0
#   Downloading libclang-18.1.1-py2.py3-none-win_amd64.whl (26.4 MB)
#      ---------------------------------------- 26.4/26.4 MB 3.4 MB/s eta 0:00:00
# Collecting opt_einsum>=2.3.2
#   Downloading opt_einsum-3.4.0-py3-none-any.whl (71 kB)
#      ---------------------------------------- 71.9/71.9 kB 1.9 MB/s eta 0:00:00
# Collecting protobuf>=5.28.0
#   Downloading protobuf-6.33.2-cp310-abi3-win_amd64.whl (436 kB)
#      -------------------------------------- 436.9/436.9 kB 2.3 MB/s eta 0:00:00
# Collecting requests<3,>=2.21.0
#   Downloading requests-2.32.5-py3-none-any.whl (64 kB)
#      -------------------------------------- 64.7/64.7 kB 698.7 kB/s eta 0:00:00
# Requirement already satisfied: setuptools in c:\users\srija\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\srija\appdata\roaming\python\python311\site-packages (from tensorflow) (1.17.0)
# Collecting termcolor>=1.1.0
#   Downloading termcolor-3.3.0-py3-none-any.whl (7.7 kB)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\srija\appdata\roaming\python\python311\site-packages (from tensorflow) (4.15.0)
# Collecting wrapt>=1.11.0
#   Downloading wrapt-2.0.1-cp311-cp311-win_amd64.whl (60 kB)
#      ---------------------------------------- 60.4/60.4 kB 1.6 MB/s eta 0:00:00
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.76.0-cp311-cp311-win_amd64.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 3.4 MB/s eta 0:00:00
# Collecting tensorboard~=2.20.0
#   Downloading tensorboard-2.20.0-py3-none-any.whl (5.5 MB)
#      ---------------------------------------- 5.5/5.5 MB 3.1 MB/s eta 0:00:00
# Collecting keras>=3.10.0
#   Downloading keras-3.13.0-py3-none-any.whl (1.5 MB)
#      ---------------------------------------- 1.5/1.5 MB 2.4 MB/s eta 0:00:00
# Collecting h5py>=3.11.0
#   Downloading h5py-3.15.1-cp311-cp311-win_amd64.whl (2.9 MB)
#      ---------------------------------------- 2.9/2.9 MB 3.1 MB/s eta 0:00:00
# Collecting ml_dtypes<1.0.0,>=0.5.1
#   Downloading ml_dtypes-0.5.4-cp311-cp311-win_amd64.whl (210 kB)
#      -------------------------------------- 210.7/210.7 kB 2.5 MB/s eta 0:00:00
# Collecting wheel<1.0,>=0.23.0
#   Downloading wheel-0.45.1-py3-none-any.whl (72 kB)
#      -------------------------------------- 72.5/72.5 kB 988.2 kB/s eta 0:00:00
# Collecting rich
#   Downloading rich-14.2.0-py3-none-any.whl (243 kB)
#      -------------------------------------- 243.4/243.4 kB 3.0 MB/s eta 0:00:00
# Collecting namex
#   Downloading namex-0.1.0-py3-none-any.whl (5.9 kB)
# Collecting optree
#   Downloading optree-0.18.0-cp311-cp311-win_amd64.whl (312 kB)
#      ------------------------------------ 312.2/312.2 kB 805.3 kB/s eta 0:00:00
# Collecting charset_normalizer<4,>=2
#   Downloading charset_normalizer-3.4.4-cp311-cp311-win_amd64.whl (106 kB)
#      ------------------------------------ 107.0/107.0 kB 887.5 kB/s eta 0:00:00
# Collecting idna<4,>=2.5
#   Downloading idna-3.11-py3-none-any.whl (71 kB)
#      ---------------------------------------- 71.0/71.0 kB 3.8 MB/s eta 0:00:00
# Collecting urllib3<3,>=1.21.1
#   Downloading urllib3-2.6.2-py3-none-any.whl (131 kB)
#      -------------------------------------- 131.2/131.2 kB 8.1 MB/s eta 0:00:00
# Collecting certifi>=2017.4.17
#   Downloading certifi-2026.1.4-py3-none-any.whl (152 kB)
#      -------------------------------------- 152.9/152.9 kB 3.0 MB/s eta 0:00:00
# Collecting markdown>=2.6.8
#   Downloading markdown-3.10-py3-none-any.whl (107 kB)
#      -------------------------------------- 107.7/107.7 kB 2.1 MB/s eta 0:00:00
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Downloading tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Collecting werkzeug>=1.0.1
#   Downloading werkzeug-3.1.4-py3-none-any.whl (224 kB)
#      -------------------------------------- 225.0/225.0 kB 1.2 MB/s eta 0:00:00
# Collecting markupsafe>=2.1.1
#   Downloading markupsafe-3.0.3-cp311-cp311-win_amd64.whl (15 kB)
# Collecting markdown-it-py>=2.2.0
#   Downloading markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
#      -------------------------------------- 87.3/87.3 kB 448.1 kB/s eta 0:00:00
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\srija\appdata\roaming\python\python311\site-packages (from rich->keras>=3.10.0->tensorflow) (2.19.2)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: namex, libclang, flatbuffers, wrapt, wheel, urllib3, termcolor, tensorboard-data-server, pyparsing, protobuf, pillow, optree, opt_einsum, numpy, mdurl, markupsafe, markdown, kiwisolver, idna, grpcio, google_pasta, gast, fonttools, cycler, charset_normalizer, certifi, absl-py, werkzeug, requests, ml_dtypes, markdown-it-py, h5py, contourpy, astunparse, tensorboard, rich, matplotlib, keras, tensorflow
# Successfully installed absl-py-2.3.1 astunparse-1.6.3 certifi-2026.1.4 charset_normalizer-3.4.4 contourpy-1.3.3 cycler-0.12.1 flatbuffers-25.12.19 fonttools-4.61.1 gast-0.7.0 google_pasta-0.2.0 grpcio-1.76.0 h5py-3.15.1 idna-3.11 keras-3.13.0 kiwisolver-1.4.9 libclang-18.1.1 markdown-3.10 markdown-it-py-4.0.0 markupsafe-3.0.3 matplotlib-3.10.8 mdurl-0.1.2 ml_dtypes-0.5.4 namex-0.1.0 numpy-2.4.0 opt_einsum-3.4.0 optree-0.18.0 pillow-12.1.0 protobuf-6.33.2 pyparsing-3.3.1 requests-2.32.5 rich-14.2.0 tensorboard-2.20.0 tensorboard-data-server-0.7.2 tensorflow-2.20.0 termcolor-3.3.0 urllib3-2.6.2 werkzeug-3.1.4 wheel-0.45.1 wrapt-2.0.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import random
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,MaxPooling2D,Dense,Flatten,Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
X_train = np.loadtxt('input.csv',delimiter=',')
Y_train = np.loadtxt('labels.csv',delimiter=',')

X_test = np.loadtxt('input_test.csv',delimiter=',')
Y_test = np.loadtxt('labels_test.csv',delimiter=',')

# %%
X_train = X_train.reshape(len(X_train),100,100,3)
Y_train = Y_train.reshape(len(Y_train),1)

X_test = X_test.reshape(len(X_test),100,100,3)
Y_test = Y_test.reshape(len(Y_test),1)

X_train = X_train/255.0
X_test = X_test/255.0

#Data augmentation to improve training
datagen = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    zoom_range=0.2
)

# %%
print("Shape of X_train:",X_train.shape)
print("Shape of Y_train:",Y_train.shape)
print("Shape of X_test:",X_test.shape)
print("Shape of Y_test:",Y_test.shape)
# Out:
# Shape of X_train: (2000, 100, 100, 3)
# Shape of Y_train: (2000, 1)
# Shape of X_test: (400, 100, 100, 3)
# Shape of Y_test: (400, 1)

# %%
idx=random.randint(0, len(X_train))
plt.imshow(X_train[idx, :])
plt.show()

# %%
from tensorflow.keras.optimizers import Adam
model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(100,100,3)),
    MaxPooling2D((2,2)),

    Conv2D(32, (3,3), activation='relu'),
    MaxPooling2D((2,2)),

    Flatten(),
    Dense(64, activation='relu'),
    Dense(1, activation='sigmoid')
])
# Out:
# c:\Users\srija\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model = Sequential()

model.add(Conv2D(32, (3,3), activation='relu', input_shape=(100,100,3)))
model.add(MaxPooling2D((2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3,3), activation='relu'))
model.add(MaxPooling2D((2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(28, (3,3), activation='relu'))
model.add(MaxPooling2D((2,2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(120, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

# Compile model
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='binary_crossentropy',
              metrics=['accuracy'])

# Model summary
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_2 (Conv2D)               │ (None, 98, 98, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 49, 49, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 49, 49, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 47, 47, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 23, 23, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 23, 23, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 21, 21, 28)     │        16,156 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 10, 10, 28)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 10, 10, 28)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 2800)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 120)            │       336,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 120)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │           121 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 371,789 (1.42 MB)
#  Trainable params: 371,789 (1.42 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
pip install scipy
# Out:
# Collecting scipy
#   Downloading scipy-1.16.3-cp311-cp311-win_amd64.whl (38.7 MB)
#      -------------------------------------- 38.7/38.7 MB 100.7 kB/s eta 0:00:00
# Requirement already satisfied: numpy<2.6,>=1.25.2 in c:\users\srija\appdata\local\programs\python\python311\lib\site-packages (from scipy) (2.4.0)
# Installing collected packages: scipy
# Successfully installed scipy-1.16.3
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
history = model.fit(
    datagen.flow(X_train, Y_train, batch_size=32),
    epochs=30,
    validation_data=(X_test, Y_test),
    verbose=1)
# Out:
# Epoch 1/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 13s 150ms/step - accuracy: 0.4835 - loss: 0.7006 - val_accuracy: 0.5025 - val_loss: 0.6932
# Epoch 2/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 15s 232ms/step - accuracy: 0.4800 - loss: 0.6935 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 3/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 9s 134ms/step - accuracy: 0.5010 - loss: 0.6945 - val_accuracy: 0.4975 - val_loss: 0.6927
# Epoch 4/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 9s 133ms/step - accuracy: 0.5150 - loss: 0.6924 - val_accuracy: 0.5825 - val_loss: 0.6910
# Epoch 5/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.5375 - loss: 0.6907 - val_accuracy: 0.5300 - val_loss: 0.6872
# Epoch 6/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 9s 135ms/step - accuracy: 0.5305 - loss: 0.6896 - val_accuracy: 0.5975 - val_loss: 0.6768
# Epoch 7/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 130ms/step - accuracy: 0.5405 - loss: 0.6891 - val_accuracy: 0.5875 - val_loss: 0.6846
# Epoch 8/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 130ms/step - accuracy: 0.5760 - loss: 0.6803 - val_accuracy: 0.5800 - val_loss: 0.6806
# Epoch 9/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 127ms/step - accuracy: 0.5645 - loss: 0.6794 - val_accuracy: 0.5725 - val_loss: 0.6803
# Epoch 10/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 127ms/step - accuracy: 0.5675 - loss: 0.6768 - val_accuracy: 0.6175 - val_loss: 0.6648
# Epoch 11/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.5700 - loss: 0.6777 - val_accuracy: 0.6175 - val_loss: 0.6679
# Epoch 12/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 125ms/step - accuracy: 0.5735 - loss: 0.6808 - val_accuracy: 0.6225 - val_loss: 0.6643
# Epoch 13/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.5710 - loss: 0.6800 - val_accuracy: 0.5150 - val_loss: 0.6935
# Epoch 14/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 128ms/step - accuracy: 0.5620 - loss: 0.6801 - val_accuracy: 0.6150 - val_loss: 0.6626
# Epoch 15/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.5900 - loss: 0.6702 - val_accuracy: 0.6050 - val_loss: 0.6605
# Epoch 16/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 126ms/step - accuracy: 0.5880 - loss: 0.6680 - val_accuracy: 0.6300 - val_loss: 0.6631
# Epoch 17/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 163ms/step - accuracy: 0.5855 - loss: 0.6733 - val_accuracy: 0.6350 - val_loss: 0.6583
# Epoch 18/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 49s 615ms/step - accuracy: 0.5950 - loss: 0.6656 - val_accuracy: 0.6675 - val_loss: 0.6497
# Epoch 19/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 490ms/step - accuracy: 0.5945 - loss: 0.6656 - val_accuracy: 0.6475 - val_loss: 0.6358
# Epoch 20/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 128ms/step - accuracy: 0.6025 - loss: 0.6587 - val_accuracy: 0.6900 - val_loss: 0.6260
# Epoch 21/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 9s 135ms/step - accuracy: 0.6190 - loss: 0.6546 - val_accuracy: 0.6850 - val_loss: 0.6355
# Epoch 22/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 129ms/step - accuracy: 0.6230 - loss: 0.6563 - val_accuracy: 0.6525 - val_loss: 0.6309
# Epoch 23/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 130ms/step - accuracy: 0.6300 - loss: 0.6535 - val_accuracy: 0.5850 - val_loss: 0.6567
# Epoch 24/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 126ms/step - accuracy: 0.6210 - loss: 0.6542 - val_accuracy: 0.6575 - val_loss: 0.6303
# Epoch 25/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 127ms/step - accuracy: 0.6375 - loss: 0.6457 - val_accuracy: 0.6750 - val_loss: 0.6238
# Epoch 26/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 130ms/step - accuracy: 0.6345 - loss: 0.6430 - val_accuracy: 0.6100 - val_loss: 0.6352
# Epoch 27/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 125ms/step - accuracy: 0.6425 - loss: 0.6294 - val_accuracy: 0.6525 - val_loss: 0.5926
# Epoch 28/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 128ms/step - accuracy: 0.6535 - loss: 0.6302 - val_accuracy: 0.7025 - val_loss: 0.5853
# Epoch 29/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 130ms/step - accuracy: 0.6560 - loss: 0.6153 - val_accuracy: 0.7000 - val_loss: 0.5806
# Epoch 30/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 130ms/step - accuracy: 0.6490 - loss: 0.6282 - val_accuracy: 0.6600 - val_loss: 0.6383

# %%
idx2 = random.randint(0,len(Y_test))
plt.imshow(X_test[idx2,:])
plt.show()

y_pred =model.predict(X_test[idx2,:].reshape(1,100,100,3))
y_pred=y_pred>0.5

if(y_pred==0):
    pred = 'dog'
else:
    pred='cat'

print("Our model says it is a",pred)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# Our model says it is a dog

# %%
print('saved model to model.h5')
# Out:
# saved model to model.h5
